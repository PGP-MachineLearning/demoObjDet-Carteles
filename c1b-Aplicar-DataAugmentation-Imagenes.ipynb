# %% [markdown]
# # Programa auxiliar para generar transformaciones al azar en las imágenes de Carteles (cada una con su correspondiente XML) aplicando técnicas de "Data Augmentation"
# Basado y adaptado del código de https://medium.com/@bhuwanbhattarai/image-data-augmentation-and-parsing-into-an-xml-file-in-pascal-voc-format-for-object-detection-4cca3d24b33b

# %% [markdown]
# 0) Configurar los parámetros para la ejecución:

# %%
# directorios locales donde se guardan las imágenes a procesar y los XMLs (pueden ser el mismo o distinto)
img_path = 'gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/' 
xml_path = img_path

# directorio local donde se guardarán las nuevas imágenes y XMLs generados en forma temporal
out_path = 'gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/DA/'

# directorios locales donde se guardarán las nuevas imágenes generados al final (pueden ser el mismo o distinto)
final_path_img = img_path
final_path_XML = img_path

print ("Parámetros definidos.")
# Out:
# Parámetros definidos.

# %% [markdown]
# 1) Cargar librerías:

# %%
import os
import cv2
import xml.etree.cElementTree as ET
from PIL import Image
import numpy as np
import random
import shutil

print ("Librerías cargadas.")
# Out:
# Librerías cargadas.

# %% [markdown]
# 2) Montar el Drive:

# %%
# monta Google Drive:
# Nota: la primera vez se debe confirmar el uso logueandose en "Google Drive File Stream" y obteniendo código de autentificación.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# 3) Definir funciones auxiliares para Data Augmentation que se usarán luego:

# %%
# función auxiliar para aplicar PCA color augmentation
def da_pca_color(image):

    # aplica la tansformación
    assert image.ndim == 3 and image.shape[2] == 3
    assert image.dtype == np.uint8
    img = image.reshape(-1, 3).astype(np.float32)
    sf = np.sqrt(3.0/np.sum(np.var(img, axis=0)))
    img = (img - np.mean(img, axis=0))*sf 
    cov = np.cov(img, rowvar=False) # calculate the covariance matrix
    value, p = np.linalg.eig(cov) # calculation of eigen vector and eigen value 
    rand = np.random.randn(3)*0.08
    delta = np.dot(p, rand*value)
    delta = (delta*255.0).astype(np.int32)[np.newaxis, np.newaxis, :]
    img_out = np.clip(image+delta, 0, 255).astype(np.uint8)
    
    return img_out


# función auxiliar para aplicar ruido Gaussiano
def da_noiseG(image):

    # aplica la transformación
    row,col,ch= image.shape
    mean = 0
    var = 0.2
    sigma = var**0.5
    gauss = np.random.normal(mean,sigma,(row,col,ch))
    gauss = gauss.reshape(row,col,ch)
    noisy = image + gauss

    return noisy    


# función auxiliar para aplicar ruido Salt & Pepper
def da_noiseSP(image):

    # aplica la transformación
    prob = 0.05
    output = np.zeros(image.shape,np.uint8)
    thres = 1 - prob 
    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            rdn = random.random()
            if rdn < prob:
                output[i][j] = 0
            elif rdn > thres:
                output[i][j] = 255
            else:
                output[i][j] = image[i][j]

    return output    


# función auxiliar para voltear la imagen en forma vertical
def da_flip_vertical(image):

    # apica la transformación
    f_img = cv2.flip(image, 0)

    return f_img


# función auxiliar para voltear la imagen en forma horizontal
def da_flip_horizontal(image):

    # apica la transformación
    f_img = cv2.flip(image, 1)

    return f_img


# función auxiliar para rotar la imagen 90 grados
def da_rotate_90(image):

    # apica la transformación
    img_transpose = np.transpose(image, (1,0,2))
    f_img = cv2.flip(img_transpose, 1)

    return f_img


# función auxiliar para rotar la imagen 180 grados
def da_rotate_180(image):

    # apica la transformación
    f_img = cv2.flip(image, -1)

    return f_img


# función auxiliar para rotar la imagen 270 grados
def da_rotate_270(image):

    # apica la transformación
    img_transpose_270 = np.transpose(image, (1,0,2))
    f_img = cv2.flip(img_transpose_270, 0)

    return f_img

print ("Funciones de Data Augmentation para imágenes definidas.")
# Out:
# Funciones de Data Augmentation para imágenes definidas.

# %% [markdown]
# 4) Levantar la información del  XML para  la imágen que se quiere procesar  y generar transformaciones (nuevas imágenes con su XMLs):

# %%
# levanta los xml a procesar
all_xml_array = [os.path.join(xml_path, fn) for fn in os.listdir(xml_path) if fn.endswith('.xml') ]

# crea el directorio temporal si no existe
if not os.path.isdir(out_path):
  os.makedirs(out_path)

# procesa los archivos XML
new_xml_info = []
cantXMLProc = 0
cantImgGen = 0
cantXMLGen = 0
print("\n*** Comienza procesamiento de XMLs para generar nuevas imágenes ***\n")
for xml_file in all_xml_array:

    cantXMLProc = cantXMLProc + 1
    print(cantXMLProc, "> ", xml_file)

    # carga la info del XML original
    et = ET.parse(xml_file)
    element = et.getroot()
    element_objs = element.findall('object') 
    element_filename = element.find('filename').text
    img_filename = os.path.join(img_path, element_filename)
    img_split = element_filename.strip().split('.png')

    # carga la imagen
    img = cv2.imread(img_filename)
    alto, ancho, ch = img.shape

    # genera las nuevas imágenes con su correspondiente XML
    # indicar las operaciones disponibles en el vector de abajo
    #        ('c', 'ng', 'nsp', 'fv', 'fh', 'r90', 'r180', 'r270')
    # -- nota: para carteles/letras no tiene sentido voltear ni girar la imagen     
    for i in ('c', 'ng', 'nsp'):

      if i=='c':        
          # aplica la transformación PCA color
          nuevaImg = da_pca_color(img)
          nuevaImgFN = img_split[0] + '-c.png'

      elif i=='ng': 
          # aplica la transformación ruido Gaussiano
          nuevaImg = da_noiseG(img)        
          nuevaImgFN = img_split[0] + '-ng.png'      

      elif i=='nsp':
          # aplica la transformación ruido Salt & Pepper
          nuevaImg = da_noiseSP(img)
          nuevaImgFN = img_split[0] + '-nsp.png'

      elif i=='fv':
          # aplica transformación de volteo vertical
          nuevaImg = da_flip_vertical(img)
          nuevaImgFN = img_split[0] + '-fv.png'

      elif i=='fh':
          # aplica transformación de volteo horizontal 
          nuevaImg = da_flip_horizontal(img)
          nuevaImgFN = img_split[0] + '-fh.png'  

      elif i=='r90':
          # aplica rotación de 90 grados 
          nuevaImg = da_rotate_90(img)
          nuevaImgFN = img_split[0] + '-r90.png'
        
      elif i=='r180':
          # aplica rotación de 180 grados 
          nuevaImg = da_rotate_180(img)
          nuevaImgFN = img_split[0] + '-r180.png'   
      
      else:
          # aplica rotación de 270 grados 
          nuevaImg = da_rotate_270(img)
          nuevaImgFN = img_split[0] + '-r270.png'      

      # si el archivo no existe
      if not os.path.isfile(out_path + nuevaImgFN):

          # graba la nueva imagen       
          cv2.imwrite(out_path + nuevaImgFN, nuevaImg)
          cantImgGen = cantImgGen + 1
      
          # genera el XML de la nueva imagen   
          nuevo_xml_annotation = ET.Element('annotation')
          ET.SubElement(nuevo_xml_annotation, 'folder').text = final_path_img
          ET.SubElement(nuevo_xml_annotation, 'filename').text = nuevaImgFN
          ET.SubElement(nuevo_xml_annotation, 'path').text = final_path_img + nuevaImgFN

          nuevo_xml_source = ET.SubElement(nuevo_xml_annotation, 'source')
          ET.SubElement(nuevo_xml_source, 'database').text = 'Unknown'

          nuevo_xml_size = ET.SubElement(nuevo_xml_annotation, 'size')
          ET.SubElement(nuevo_xml_size, 'width').text = str(nuevaImg.shape[1])
          ET.SubElement(nuevo_xml_size, 'height').text = str(nuevaImg.shape[0])
          ET.SubElement(nuevo_xml_size, 'depth').text = str(nuevaImg.shape[2])

          ET.SubElement(nuevo_xml_annotation, 'segmented').text = '0'

          # procesa los elementos en el archivo XML original para generar el nuevo
          for element_obj in element_objs:

              # obtiene la información actual de la imagen
              class_name = element_obj.find('name').text 

              # obtiene info del box actual
              obj_bbox = element_obj.find('bndbox')
              x1 = int(round(float(obj_bbox.find('xmin').text)))
              y1 = int(round(float(obj_bbox.find('ymin').text)))
              x2 = int(round(float(obj_bbox.find('xmax').text)))
              y2 = int(round(float(obj_bbox.find('ymax').text)))
              
              # cambia las coordenadas del box de acuerdo al tipo de transformación aplicada
              if i=='c' or i=='ng' or i=='nsp':        
                # para la transformación PCA color, ruido Gaussiano y ruido Salt & Pepper  
                # quedan iguales
                f_x1 = x1
                f_x2 = x2
                f_y1 = y1
                f_y2 = y2

              elif i=='fv':
                  # para transformación de volteo vertical, cambia
                  f_x1 = x1
                  f_y1 = alto - y2
                  f_x2 = x2
                  f_y2 = alto - y1

              elif i=='fh':
                  # para transformación de volteo horizontal, cambia
                  f_x1 = ancho - x2
                  f_y1 = y1
                  f_x2 = ancho - x1
                  f_y2 = y2

              elif i=='r90':
                  # para rotación de 90 grados, cambia
                  f_x1 = alto - y2
                  f_y1 = x1
                  f_x2 = alto - y1
                  f_y2 = x2
                
              elif i=='r180':
                  # para rotación de 180 grados, cambia
                  f_x1 = ancho - x2
                  f_y1 = alto - y2
                  f_x2 = ancho - x1
                  f_y2 = alto - y1   
                
              else:
                  # para rotación de 270 grados, cambia
                  f_x1 = y1
                  f_y1 = ancho - x2
                  f_x2 = y2
                  f_y2 = ancho - x1
          
              # define el nuevo box
              nuevo_xml_object = ET.SubElement(nuevo_xml_annotation, 'object')
              ET.SubElement(nuevo_xml_object, 'name').text = class_name
              ET.SubElement(nuevo_xml_object, 'pose').text = 'Unspecified'
              ET.SubElement(nuevo_xml_object, 'truncated').text = '0'
              ET.SubElement(nuevo_xml_object, 'difficult').text = '0'

              nuevo_xml_bndbox = ET.SubElement(nuevo_xml_object, 'bndbox')
              ET.SubElement(nuevo_xml_bndbox, 'xmin').text = str(f_x1)
              ET.SubElement(nuevo_xml_bndbox, 'ymin').text = str(f_y1)
              ET.SubElement(nuevo_xml_bndbox, 'xmax').text = str(f_x2)
              ET.SubElement(nuevo_xml_bndbox, 'ymax').text = str(f_y2)


          # graba el nuevo XML
          nuevoXMLfn = nuevaImgFN.replace(".png", ".xml")
          xml_tree = ET.ElementTree(nuevo_xml_annotation)
          xml_tree.write( out_path + nuevoXMLfn )
          cantXMLGen = cantXMLGen + 1

print("\n*** Fin procesamiento de de XMLs para generar nuevas imágenes ***\n")
print("> Imágenes/XMLs procesados: ", cantXMLProc)
print("> Imágenes nuevas generadas: ", cantImgGen)
print("> XMLs nuevas generados: ", cantXMLGen)
# Out:
# *** Comienza procesamiento de XMLs para generar nuevas imágenes ***
#
# 1 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_1_JXFA903.xml
# 2 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_2_82J.xml
# 3 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_3_93RUJ8VYIO.xml
# 4 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_4_HH.xml
# 5 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_5_F35.xml
# 6 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_6_77.xml
# 7 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_7_386Y25UG.xml
# 8 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_8_NI2M.xml
# 9 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_9_S2SGH3XF09.xml
# 10 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_10_0YLFJRSJ3U.xml
# 11 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_11_K7THI4H.xml
# 12 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_12_E4CT.xml
# 13 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_13_MLSVIM.xml
# 14 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_14_YZD418.xml
# 15 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_15_R89JYMO.xml
# 16 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_16_RULX35QCRI.xml
# 17 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_17_P0OCUBPF5.xml
# 18 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_18_HK49XJ.xml
# 19 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_19_M49RI6LT.xml
# 20 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_20_8NY.xml
# 21 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_21_4N8C2Q.xml
# 22 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_22_VMD1927E3.xml
# 23 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_23_RMZ7C6CC.xml
# 24 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_24_EDA2TM09.xml
# 25 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_25_X5.xml
# 26 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_26_2I61.xml
# 27 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_27_IE1GQU2N.xml
# 28 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_28_6TZF9PVXLU.xml
# 29 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_29_4QZ5LTUJHG.xml
# 30 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_30_6W4.xml
# 31 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_31_K39.xml
# 32 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_32_VPH.xml
# 33 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_33_VFGUZNV1M6.xml
# 34 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_34_JWBR1X.xml
# 35 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_35_MJ2AIH2ZZ.xml
# 36 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_36_IW9WQ4.xml
# 37 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_37_5OWHP.xml
# 38 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_38_Y2.xml
# 39 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_39_I91JK6.xml
# 40 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_40_T8WTELPEXG.xml
# 41 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_41_8W72J.xml
# 42 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_42_UPXHQ.xml
# 43 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_43_IKKJ6.xml
# 44 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_44_59.xml
# 45 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_45_JDLTUV.xml
# 46 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_46_HJ572KF6Q.xml
# 47 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_47_1DM6W.xml
# 48 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_48_5Z.xml
# 49 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_49_H7HH3L0.xml
# 50 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_50_BBKB4.xml
# 51 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_51_BMDR1G4.xml
# 52 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_52_R50.xml
# 53 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_53_TDSR.xml
# 54 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_54_K1MV.xml
# 55 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_55_91H968U.xml
# 56 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_56_2XJ.xml
# 57 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_57_J43MKFFG.xml
# 58 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_58_JQHP2S.xml
# 59 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_59_MTNXHTGU8K.xml
# 60 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_60_OTTSCZKARD.xml
# 61 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_61_R7EG5Y96F.xml
# 62 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_62_SVKT7KHT6.xml
# 63 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_63_SARRX2MCCD.xml
# 64 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_64_Y6.xml
# 65 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_65_FB4EPU9SNE.xml
# 66 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_66_WW2WRSZBEL.xml
# 67 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_67_TSQLE9WFZR.xml
# 68 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_68_KDQ.xml
# 69 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_69_O63.xml
# 70 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_70_JEC.xml
# 71 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_71_0V5.xml
# 72 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_72_48LHXNK.xml
# 73 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_73_M7M.xml
# 74 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_74_RHKW.xml
# 75 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_75_Z4WBKNST.xml
# 76 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_76_NVT2T46.xml
# 77 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_77_IJFM85UD.xml
# 78 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_78_DSAKJ.xml
# 79 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_79_P5.xml
# 80 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_80_GWIST2.xml
# 81 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_81_J9C2CY.xml
# 82 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_82_L2MMHB9.xml
# 83 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_83_WZL.xml
# 84 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_84_JN5.xml
# 85 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_85_Y6KW8.xml
# 86 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_86_NS.xml
# 87 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_87_GYUAMBRX.xml
# 88 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_88_QOWD.xml
# 89 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_89_WTWKAH.xml
# 90 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_90_VGOV9JL2U.xml
# 91 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_91_XN.xml
# 92 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_92_IDPG949NSM.xml
# 93 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_93_JWZ1H37H.xml
# 94 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_94_X13MP.xml
# 95 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_95_2BYH.xml
# 96 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_96_S0JJ.xml
# 97 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_97_4KPCMV.xml
# 98 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_98_9O5IAMNR.xml
# 99 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_99_W8.xml
# 100 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_100_YEYC.xml
# 101 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_101_SGIABG5.xml
# 102 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_102_W8FMS.xml
# 103 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_103_UUD.xml
# 104 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_104_7V6AM.xml
# 105 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_105_7HW5AK.xml
# 106 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_106_YDP9FCC7.xml
# 107 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_107_FM7C.xml
# 108 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_108_TQOQXZPF.xml
# 109 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_109_4KOH.xml
# 110 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_110_MLJQFEPXQ4.xml
# 111 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_111_EF.xml
# 112 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_112_55TJE.xml
# 113 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_113_TL3F0M7.xml
# 114 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_114_MC.xml
# 115 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_115_6PZTF.xml
# 116 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_116_QFK.xml
# 117 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_117_LQUISS5P47.xml
# 118 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_118_BAT0DX.xml
# 119 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_119_FTSI5OX5J.xml
# 120 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_120_S9SY2.xml
# 121 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_121_8UDV0Z.xml
# 122 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_122_GBSQIK7FT.xml
# 123 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_123_HUDGKRR9QE.xml
# 124 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_124_N0U.xml
# 125 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_125_IH1MRI12T.xml
# 126 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_126_USJ.xml
# 127 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_127_NKWD6F.xml
# 128 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_128_YAL103.xml
# 129 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_129_KEH7Y3GZT.xml
# 130 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_130_5U5F.xml
# 131 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_131_F5L.xml
# 132 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_132_QL9M7KT.xml
# 133 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_133_4H.xml
# 134 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_134_OXF9IF.xml
# 135 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_135_Q21.xml
# 136 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_136_FSASQI.xml
# 137 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_137_8OD3W0.xml
# 138 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_138_W3XHEJZ.xml
# 139 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_139_AQZRTV56.xml
# 140 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_140_ZH3HGANM.xml
# 141 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_141_OL.xml
# 142 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_142_3YW6.xml
# 143 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_143_OURTEI.xml
# 144 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_144_ENCES.xml
# 145 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_145_43T.xml
# 146 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_146_I4B.xml
# 147 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_147_FQQPG6E74.xml
# 148 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_148_CYZIN.xml
# 149 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_149_UCL.xml
# 150 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_150_1Q1R8L.xml
# 151 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_151_H9EI5ZIF.xml
# 152 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_152_MM.xml
# 153 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_153_HYDEXV5.xml
# 154 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_154_XGIRF.xml
# 155 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_155_NF0JA6TG.xml
# 156 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_156_FH4H.xml
# 157 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_157_NM8ZZEPZS.xml
# 158 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_158_R7AO7OGGM.xml
# 159 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_159_HDTLNIODC.xml
# 160 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_160_IH.xml
# 161 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_161_MMV59K.xml
# 162 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_162_ZUH.xml
# 163 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_163_86U1LP54QW.xml
# 164 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_164_WUV8O1.xml
# 165 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_165_2EEB6.xml
# 166 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_166_FS.xml
# 167 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_167_CV1FYK.xml
# 168 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_168_NCHK2T48.xml
# 169 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_169_MR.xml
# 170 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_170_MIKAWOFN.xml
# 171 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_171_S0T10POFPD.xml
# 172 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_172_WO82G.xml
# 173 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_173_APLXU0608.xml
# 174 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_174_W5EJ.xml
# 175 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_175_YIBT.xml
# 176 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_176_DSOH.xml
# 177 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_177_VHZO3VV.xml
# 178 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_178_3QFC4B1N3M.xml
# 179 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_179_DEG393O77.xml
# 180 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_180_FIO.xml
# 181 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_181_GPEKTZXD.xml
# 182 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_182_Z0.xml
# 183 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_183_N96NB.xml
# 184 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_184_NAR3607.xml
# 185 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_185_ECMAHCZ8.xml
# 186 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_186_D2L9V.xml
# 187 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_187_CMH4HI9.xml
# 188 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_188_VC2L15I.xml
# 189 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_189_9MP.xml
# 190 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_190_2O7.xml
# 191 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_191_92HU3ZK7.xml
# 192 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_192_YQ.xml
# 193 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_193_EIN6BT.xml
# 194 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_194_GHE8Y3X.xml
# 195 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_195_6BO.xml
# 196 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_196_77H9.xml
# 197 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_197_SI.xml
# 198 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_198_73BSVHDQWJ.xml
# 199 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_199_D1S.xml
# 200 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_200_KKDPFB4ZU.xml
# 201 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_201_EEUCW9I9AV.xml
# 202 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_202_3P84UX.xml
# 203 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_203_DCCS6.xml
# 204 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_204_416CU.xml
# 205 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_205_V0YTWGCPTX.xml
# 206 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_206_L6ATO3N28.xml
# 207 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_207_1P40I.xml
# 208 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_208_HNVHL.xml
# 209 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_209_Y8Q4D2YU6.xml
# 210 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_210_1XYXKF6.xml
# 211 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_211_MG01RL.xml
# 212 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_212_Y5.xml
# 213 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_213_Z56JDQ58.xml
# 214 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_214_XMERYC7BV.xml
# 215 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_215_M169.xml
# 216 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_216_HBR3.xml
# 217 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_217_K9P7DT.xml
# 218 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_218_UA458Y6.xml
# 219 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_219_JQBEA.xml
# 220 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_220_QNHONYIG.xml
# 221 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_221_K7VDQTA.xml
# 222 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_222_D42W.xml
# 223 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_223_1IGFEMH.xml
# 224 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_224_0QAFLYCO41.xml
# 225 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_225_KGX18U.xml
# 226 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_226_IHKHDVSU.xml
# 227 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_227_ESYIL.xml
# 228 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_228_8TVFNHRGW.xml
# 229 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_229_X6N.xml
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: ComplexWarning: Casting complex values to real discards the imaginary part
#   del sys.path[0]
# 230 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_230_EW6PJ.xml
# 231 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_231_W4.xml
# 232 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_232_AUPI55I.xml
# 233 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_233_2I845A.xml
# 234 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_234_ONOW4A7S.xml
# 235 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_235_A39TOL81R.xml
# 236 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_236_6RML.xml
# 237 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_237_DRY.xml
# 238 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_238_H9HBCM6.xml
# 239 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_239_JQ.xml
# 240 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_240_A32.xml
# 241 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_241_A54H82GXKP.xml
# 242 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_242_INC.xml
# 243 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_243_YY8.xml
# 244 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_244_LU7AQDHVW.xml
# 245 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_245_8TNBQ2E.xml
# 246 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_246_2YE4T8.xml
# 247 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_247_ECI0G.xml
# 248 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_248_WPB7TG1.xml
# 249 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_249_CRF3YJ.xml
# 250 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_250_T76YOJ.xml
# 251 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_251_T0YKJ9U.xml
# 252 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_252_0G9.xml
# 253 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_253_MFLZ11EZ.xml
# 254 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_254_9PYYRL5.xml
# 255 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_255_RX.xml
# 256 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_256_XKM1CZJ1R7.xml
# 257 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_257_29.xml
# 258 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_258_FPSQVJ.xml
# 259 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_259_QN.xml
# 260 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_260_N2KKY.xml
# 261 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_261_ED.xml
# 262 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_262_4S71WF.xml
# 263 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_263_LF8HFN.xml
# 264 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_264_UT086SUZ8.xml
# 265 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_265_M6M.xml
# 266 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_266_1ER9AS.xml
# 267 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_267_JFOXCRUS8L.xml
# 268 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_268_UQBX3.xml
# 269 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_269_GX.xml
# 270 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_270_H74T6.xml
# 271 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_271_5BF6OL6Z3N.xml
# 272 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_272_X4A4U65G.xml
# 273 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_273_C1.xml
# 274 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_274_67SYPZ1LD.xml
# 275 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_275_S1GB0HTXZ.xml
# 276 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_276_1HO4W7.xml
# 277 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_277_V7G9DRQ2.xml
# 278 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_278_MKV.xml
# 279 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_279_NZTQ.xml
# 280 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_280_7ZYJA.xml
# 281 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_281_B43UGE6M.xml
# 282 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_282_M064HENG4I.xml
# 283 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_283_WUMHJ.xml
# 284 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_284_GD40GFI7.xml
# 285 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_285_AXH.xml
# 286 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_286_UHCY0TU.xml
# 287 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_287_37.xml
# 288 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_288_ED.xml
# 289 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_289_831I29K.xml
# 290 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_290_DF3SMVBC.xml
# 291 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_291_IXN.xml
# 292 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_292_ULM8RX.xml
# 293 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_293_Y3FHO.xml
# 294 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_294_DB.xml
# 295 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_295_DF9RXW.xml
# 296 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_296_0SLFIPS3ZJ.xml
# 297 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_297_4VRNSLFITW.xml
# 298 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_298_UXI.xml
# 299 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_299_0U8G.xml
# 300 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_300_D5H5KH.xml
# 301 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_301_54Y.xml
# 302 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_302_FXZR.xml
# 303 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_303_XH1FU9N9F7.xml
# 304 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_304_P6T.xml
# 305 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_305_K1EGJ6MW3.xml
# 306 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_306_GVTRWS5S.xml
# 307 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_307_N3.xml
# 308 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_308_H2ZOJ9.xml
# 309 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_309_UVMFW3QR.xml
# 310 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_310_6H.xml
# 311 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_311_SQBIVL6.xml
# 312 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_312_A1331RN.xml
# 313 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_313_F2P8Q.xml
# 314 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_314_SQYPC.xml
# 315 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_315_3V1M.xml
# 316 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_316_7Z39U3A.xml
# 317 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_317_FL7PUP.xml
# 318 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_318_KZOWPCKL.xml
# 319 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_319_7H9WG.xml
# 320 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_320_C107NGRO.xml
# 321 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_321_H8JVB.xml
# 322 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_322_RMM2.xml
# 323 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_323_1D.xml
# 324 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_324_4A0WM9H1.xml
# 325 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_325_0GNJB.xml
# 326 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_326_6PHC82BP.xml
# 327 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_327_4TXP0IN1.xml
# 328 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_328_4MLULPPON.xml
# 329 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_329_QWNPM4E.xml
# 330 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_330_JMIDCK.xml
# 331 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_331_4XC503BNDX.xml
# 332 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_332_NS.xml
# 333 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_333_N69DZ89.xml
# 334 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_334_HP16.xml
# 335 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_335_G2KR06B.xml
# 336 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_336_NS.xml
# 337 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_337_69U1N171.xml
# 338 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_338_V3M580.xml
# 339 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_339_GOZIMSJUA.xml
# 340 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_340_MJBD3507R.xml
# 341 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_341_358P4W0D.xml
# 342 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_342_TES2QKGY6.xml
# 343 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_343_X1OLU5UV.xml
# 344 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_344_JGGCK5K.xml
# 345 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_345_S0P.xml
# 346 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_346_KGDS.xml
# 347 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_347_NLV.xml
# 348 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_348_TWX4.xml
# 349 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_349_J9.xml
# 350 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_350_9FWXW.xml
# 351 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_351_CNI.xml
# 352 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_352_X357S.xml
# 353 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_353_CKFM.xml
# 354 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_354_EVRR.xml
# 355 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_355_L69.xml
# 356 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_356_M193SNZZIR.xml
# 357 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_357_D778WB52Z.xml
# 358 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_358_E6ZC.xml
# 359 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_359_77KOFX08H.xml
# 360 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_360_O8.xml
# 361 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_361_VF0J6XT.xml
# 362 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_362_H484WAS9D.xml
# 363 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_363_V9.xml
# 364 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_364_I6.xml
# 365 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_365_T4DR4CM.xml
# 366 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_366_4WXO.xml
# 367 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_367_TF98.xml
# 368 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_368_JRM2BTG.xml
# 369 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_369_5ITEG9.xml
# 370 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_370_W5HYMQ.xml
# 371 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_371_O5BD6QVFR3.xml
# 372 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_372_UHLWP.xml
# 373 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_373_8HE.xml
# 374 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_374_849G8C40NE.xml
# 375 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_375_Z78IM.xml
# 376 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_376_4W.xml
# 377 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_377_4H57E9LZ2L.xml
# 378 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_378_UXJ.xml
# 379 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_379_A9POPVJLA.xml
# 380 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_380_FB4.xml
# 381 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_381_M3UA.xml
# 382 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_382_8ITGOM.xml
# 383 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_383_LG.xml
# 384 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_384_SO.xml
# 385 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_385_HCNXMDKZH9.xml
# 386 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_386_QGF.xml
# 387 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_387_6F5G.xml
# 388 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_388_G53.xml
# 389 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_389_J4CIL.xml
# 390 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_390_Q7.xml
# 391 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_391_2UH.xml
# 392 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_392_L8F.xml
# 393 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_393_6ZZ23F.xml
# 394 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_394_HYAP.xml
# 395 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_395_VUNS.xml
# 396 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_396_8UK6HPNWP6.xml
# 397 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_397_O3.xml
# 398 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_398_ADI.xml
# 399 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_399_BHTY.xml
# 400 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_400_3Y.xml
# 401 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_401_MOWKIH7V8.xml
# 402 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_402_PQSEFFFA.xml
# 403 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_403_O3E4NLY.xml
# 404 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_404_RFGJZNI.xml
# 405 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_405_4ZNJOJ.xml
# 406 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_406_VQCVAWMB.xml
# 407 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_407_UM.xml
# 408 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_408_7EHB1Q.xml
# 409 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_409_WI.xml
# 410 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_410_INKI.xml
# 411 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_411_TF08.xml
# 412 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_412_MXKTXRXBFR.xml
# 413 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_413_1VXOGUDQ.xml
# 414 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_414_3Q22IWDF.xml
# 415 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_415_N09KNICY.xml
# 416 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_416_6Z91T.xml
# 417 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_417_J6M53IJ5Y0.xml
# 418 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_418_BXTHKO.xml
# 419 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_419_X3YHOY37D9.xml
# 420 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_420_JNMX3TGOE.xml
# 421 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_421_F7.xml
# 422 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_422_R7M3D.xml
# 423 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_423_LZQUU.xml
# 424 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_424_3TY9ZO67X.xml
# 425 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_425_SAUS5.xml
# 426 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_426_F7.xml
# 427 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_427_3HZE18CHL.xml
# 428 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_428_J2K.xml
# 429 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_429_GUQKB.xml
# 430 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_430_RVQZ.xml
# 431 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_431_BMC32.xml
# 432 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_432_N132EWR.xml
# 433 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_433_J3NNLSYPEU.xml
# 434 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_434_84.xml
# 435 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_435_FC21KH.xml
# 436 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_436_NM87US0L1.xml
# 437 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_437_RHUAZ0BDY.xml
# 438 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_438_06.xml
# 439 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_439_SMWZH.xml
# 440 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_440_XZDW.xml
# 441 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_441_ME.xml
# 442 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_442_FVBPLSGFJ.xml
# 443 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_443_S89J4WA.xml
# 444 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_444_NUB0.xml
# 445 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_445_6H8LNIJP.xml
# 446 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_446_61NOSA6.xml
# 447 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_447_XWA8KGLOG.xml
# 448 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_448_JO05YNZQAH.xml
# 449 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_449_GCI76.xml
# 450 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_450_LFBY.xml
# 451 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_451_IWD8.xml
# 452 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_452_EROHMCO2NC.xml
# 453 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_453_AAB6PX0.xml
# 454 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_454_DGR5.xml
# 455 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_455_FFHU4.xml
# 456 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_456_8E3.xml
# 457 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_457_JRQN3CT0X.xml
# 458 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_458_BOKYZ.xml
# 459 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_459_30Y8NP3I6I.xml
# 460 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_460_NFU0FTLMD.xml
# 461 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_461_G30VZ.xml
# 462 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_462_GNQ9.xml
# 463 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_463_M6.xml
# 464 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_464_MMC4MK4PM.xml
# 465 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_465_86B1C4F.xml
# 466 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_466_ZR.xml
# 467 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_467_UP5.xml
# 468 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_468_PNCLCQ1VK6.xml
# 469 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_469_KG2I.xml
# 470 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_470_R7ZJRRIBGT.xml
# 471 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_471_VAJXTG3V1.xml
# 472 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_472_6RM8.xml
# 473 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_473_07UQTZO8X.xml
# 474 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_474_ONGC.xml
# 475 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_475_UCSHP.xml
# 476 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_476_1MV657WC.xml
# 477 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_477_S6UZ76MLHV.xml
# 478 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_478_BTQ9KPPG.xml
# 479 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_479_9K.xml
# 480 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_480_JN45.xml
# 481 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_481_SRMLLIIM.xml
# 482 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_482_ORMFM0X.xml
# 483 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_483_HD1AGY9A.xml
# 484 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_484_0A.xml
# 485 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_485_915FY4.xml
# 486 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_486_WI.xml
# 487 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_487_W1GJSM.xml
# 488 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_488_MGBW1Y.xml
# 489 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_489_6P.xml
# 490 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_490_CY0YVH.xml
# 491 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_491_PP7.xml
# 492 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_492_6EBYQW.xml
# 493 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_493_S4V.xml
# 494 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_494_W3EYYVU40.xml
# 495 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_495_K2QF8X7.xml
# 496 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_496_LZ02VJ.xml
# 497 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_497_TK3R24KDCY.xml
# 498 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_498_58KFO8M.xml
# 499 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_499_DX.xml
# 500 >  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/cartel_500_P31.xml
#
# *** Fin procesamiento de de XMLs para generar nuevas imágenes ***
#
# > Imágenes/XMLs procesados:  500
# > Imágenes nuevas generadas:  1500
# > XMLs nuevas generados:  1500

# %% [markdown]
# 5) Mover las imágenes nuevas generasdas con su XMLs al carpeta final para su procesamiento:

# %%
# levanta la lista de imágenes de cada letra
allFileNames = [ fn for fn in os.listdir(out_path) if fn.endswith('.png') ]

cantIm = 0
cantXML = 0

if not os.path.isdir(final_path_img):
  os.makedirs(final_path_img)

if not os.path.isdir(final_path_XML):
  os.makedirs(final_path_XML)

for name in allFileNames:
  # mueve la imagen
  if os.path.isfile(final_path_img + '/' + name):
    print("**", name, " ya existe en ", final_path_img)      
  else:
    shutil.move(out_path + '/' + name, final_path_img)
    cantIm = cantIm + 1
  # mueve el xml
  nameXML = name.replace(".png", ".xml")
  if os.path.isfile(final_path_XML + '/' + nameXML):
    print("**", nameXML, " ya existe en ", final_path_XML)      
  else:
    shutil.move(out_path + '/' + nameXML, final_path_XML)
    cantXML = cantXML + 1

print(cantIm, " imágenes movidas a ", final_path_img)
print(cantXML, " XML movidos a ", final_path_XML)
print("\n")
# Out:
# 1500  imágenes movidas a  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/
# 1500  XML movidos a  gdrive/My Drive/IA/demoObjDet-Carteles/Carteles/
